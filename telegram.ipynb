# %%
import telepot
import pandas as pd
bot = telepot.Bot('1913570782:AAHIrTJDK7-toxsxqOv27Dh9wYU2d5HYfgk')
bot.getMe()
import requests
import time
import urllib
from datetime import date

import pandas as pd
import time
import sys

# local modules
from binance.client import Client
from binance.enums import *
from indicator import indicators

# local file
import secrets
from configparser import ConfigParser
import yfinance as yf
import numpy as np
import datetime as dt
import requests 
import json 
import pandas as pd 
import numpy as np  
from finta import TA

df3 = pd.read_csv("parameters.csv")
df3.set_index("parameters",inplace=True)
df1=df3.T
client = Client((df1['binance_api_key'][0]), str(df1['binance_api_secret_key'][0]))
j=0

# %%
from pprint import pprint
response = bot.getUpdates()
pprint(response)

# %%
    if len(response)>j:
        if 'document' in response[-1]['message']:
            
            # if response[-1]['message']['document']['file_name'].upper()=='STOCKS.CSV':
                
            #     file_id=response[-1]['message']['document']['file_id']
            
            #     endpoint=r"https://api.telegram.org/bot1715056219:AAGxytb3U1gIt1vlVn8Jf5b4za3E1HPuOd4/getFile?file_id={}".format(file_id)
            #     content=requests.get(url=endpoint)
            #     content=content.json()
            
            #     file_path=content['result']['file_path']
            #     endpoint=r"https://api.telegram.org/file/bot1715056219:AAGxytb3U1gIt1vlVn8Jf5b4za3E1HPuOd4/{}".format(file_path)
            #     req = requests.get(endpoint)
            #     url_content = req.content
            #     csv_file = open('stocks.csv', 'wb')
            
            #     csv_file.write(url_content)
            #     csv_file.close()
            
            #     bot.sendDocument(1039725953, document=open('stocks.csv', 'rb'))
            #     bot.sendMessage(1039725953,'please veriy if the stocks are updated or not')

            if response[-1]['message']['document']['file_name'].upper()=='PARAMETERS.CSV':
                file_id=response[-1]['message']['document']['file_id']
            
                endpoint=r"https://api.telegram.org/bot1913570782:AAHIrTJDK7-toxsxqOv27Dh9wYU2d5HYfgk/getFile?file_id={}".format(file_id)
                content=requests.get(url=endpoint)
                content=content.json()
            
                file_path=content['result']['file_path']
                endpoint=r"https://api.telegram.org/file/bot1913570782:AAHIrTJDK7-toxsxqOv27Dh9wYU2d5HYfgk/{}".format(file_path)
                req = requests.get(endpoint)
                url_content = req.content
                csv_file = open('parameters.csv', 'wb')
            
                csv_file.write(url_content)
                csv_file.close()
            
                bot.sendDocument(1039725953, document=open('parameters.csv.csv', 'rb'))
                bot.sendMessage(1039725953,'please veriy if the parameters are updated or not')

            
        else:
            message=response[-1]['message']['text']
            
            message=message.upper()
            # if message=='SEE STOCKS':
                
            #     bot.sendDocument(1039725953, document=open('stocks.csv', 'rb'))

            # if message=='CHANGE STOCKS':
            #     bot.sendMessage(1039725953,'please first write "SEE STOCKS" and have the list of presently running stocks and make all the changes you want and then send it back' )


            if message=='SEE PARAMETERS':
                bot.sendDocument(1039725953, document=open('parameters.csv', 'rb'))
            
            elif message=='STOP BOT':
                df3 = pd.read_csv("parameters.csv")
                df3['value'][-1]='off'
                df3.to_csv('parameters.csv')
                bot.sendMessage(1039725953,'Bot has been stopped')


            elif message=='START BOT':

                df3 = pd.read_csv("parameters.csv")
                df3['value'][-1]='on'
                df3.to_csv('parameters.csv')
                bot.sendMessage(1039725953,'Bot has been started')






    j=len(response)

# %%
import telepot
bot = telepot.Bot('1913570782:AAHIrTJDK7-toxsxqOv27Dh9wYU2d5HYfgk')
bot.getMe()
# Out:
# {'id': 1913570782,
#  'is_bot': True,
#  'first_name': 'binance_strategy',
#  'username': 'binance_883_bot',
#  'can_join_groups': True,
#  'can_read_all_group_messages': False,
#  'supports_inline_queries': False}

# %%
>>> from pprint import pprint
>>> response = bot.getUpdates()
>>> pprint(response)
# Out:
# [{'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630238032,
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 15871,
#               'text': 'Start bot'},
#   'update_id': 997768017},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630245669,
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 15897,
#               'text': 'see parameters'},
#   'update_id': 997768018},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630245847,
#               'document': {'file_id': 'BQACAgUAAxkBAAI-ImErk9eba_eD0x7jZodI0DcMnzS4AAJuAwACBExZVQHCNZehEXQDIAQ',
#                            'file_name': 'parameters.csv',
#                            'file_size': 387,
#                            'file_unique_id': 'AgADbgMAAgRMWVU',
#                            'mime_type': 'text/csv'},
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 15906},
#   'update_id': 997768019},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630246224,
#               'document': {'file_id': 'BQACAgUAAxkBAAI_DWErlVBXEfwriXOgzOItKzoudSM_AAKCAwACBExZVfD0NdlAdfzrIAQ',
#                            'file_name': 'parameters.csv',
#                            'file_size': 387,
#                            'file_unique_id': 'AgADggMAAgRMWVU',
#                            'mime_type': 'text/csv'},
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 16141},
#   'update_id': 997768020},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630246254,
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 16171,
#               'text': 'SEE PARAMETERS'},
#   'update_id': 997768021},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630246347,
#               'document': {'file_id': 'BQACAgUAAxkBAAI_L2ErlcvxZOrkEBd3TtW-9HZKmogVAAKJAwACBExZVYbc0yTDO3X_IAQ',
#                            'file_name': 'parameters.csv',
#                            'file_size': 387,
#                            'file_unique_id': 'AgADiQMAAgRMWVU',
#                            'mime_type': 'text/csv'},
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 16175},
#   'update_id': 997768022},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630247301,
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 16648,
#               'text': 'See parameters'},
#   'update_id': 997768023},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630266888,
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 17099,
#               'text': 'see parameters'},
#   'update_id': 997768024},
#  {'edited_message': {'chat': {'first_name': 'Nicolas',
#                               'id': 665596324,
#                               'last_name': '♛',
#                               'type': 'private',
#                               'username': 'nicolascane'},
#                      'date': 1630182697,
#                      'edit_date': 1630273754,
#                      'from': {'first_name': 'Nicolas',
#                               'id': 665596324,
#                               'is_bot': False,
#                               'language_code': 'it',
#                               'last_name': '♛',
#                               'username': 'nicolascane'},
#                      'message_id': 14362,
#                      'text': 'STOP BOT'},
#   'update_id': 997768025},
#  {'message': {'chat': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'last_name': '♛',
#                        'type': 'private',
#                        'username': 'nicolascane'},
#               'date': 1630273760,
#               'from': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'is_bot': False,
#                        'language_code': 'it',
#                        'last_name': '♛',
#                        'username': 'nicolascane'},
#               'message_id': 17271,
#               'text': 'STOP BOT'},
#   'update_id': 997768026},
#  {'message': {'chat': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'last_name': '♛',
#                        'type': 'private',
#                        'username': 'nicolascane'},
#               'date': 1630273768,
#               'from': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'is_bot': False,
#                        'language_code': 'it',
#                        'last_name': '♛',
#                        'username': 'nicolascane'},
#               'message_id': 17289,
#               'text': 'SEE PARAMETERS'},
#   'update_id': 997768027},
#  {'message': {'chat': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'last_name': '♛',
#                        'type': 'private',
#                        'username': 'nicolascane'},
#               'date': 1630273916,
#               'document': {'file_id': 'BQACAgQAAxkBAAJEgmEsAXz8tqKZuoJi97jTHN8LqdZHAAJ-DwACy_xgUQRDrd1GsaZGIAQ',
#                            'file_name': 'parameters.csv',
#                            'file_size': 384,
#                            'file_unique_id': 'AgADfg8AAsv8YFE',
#                            'mime_type': 'text/csv'},
#               'from': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'is_bot': False,
#                        'language_code': 'it',
#                        'last_name': '♛',
#                        'username': 'nicolascane'},
#               'message_id': 17538},
#   'update_id': 997768028},
#  {'message': {'chat': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'last_name': '♛',
#                        'type': 'private',
#                        'username': 'nicolascane'},
#               'date': 1630273954,
#               'from': {'first_name': 'Nicolas',
#                        'id': 665596324,
#                        'is_bot': False,
#                        'language_code': 'it',
#                        'last_name': '♛',
#                        'username': 'nicolascane'},
#               'message_id': 17550,
#               'text': 'START BOT'},
#   'update_id': 997768029},
#  {'message': {'chat': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'type': 'private',
#                        'username': 'Sudhanshu_883'},
#               'date': 1630296960,
#               'from': {'first_name': 'sudhanshu',
#                        'id': 1039725953,
#                        'is_bot': False,
#                        'language_code': 'en',
#                        'username': 'Sudhanshu_883'},
#               'message_id': 24103,
#               'text': 'See parameters'},
#   'update_id': 997768030}]

# %%
file_id=response[-1]['message']['document']['file_id']
pprint(response[-1])
pprint(response[-1]['message']['document']['file_id'])
endpoint=r"https://api.telegram.org/bot1913570782:AAHIrTJDK7-toxsxqOv27Dh9wYU2d5HYfgk/getFile?file_id={}".format(file_id)
content=requests.get(url=endpoint)
content=content.json()
print(content)
file_path=content['result']['file_path']
endpoint=r"https://api.telegram.org/file/bot1913570782:AAHIrTJDK7-toxsxqOv27Dh9wYU2d5HYfgk/{}".format(file_path)
req = requests.get(endpoint)
url_content = req.content
csv_file = open('parameters.csv', 'wb')

csv_file.write(url_content)
csv_file.close()

bot.sendDocument(1039725953, document=open('parameters.csv', 'rb'))
bot.sendDocument(665596324, document=open('parameters.csv', 'rb'))
bot.sendMessage(1039725953,'please veriy if the parameters are updated or not')
bot.sendMessage(665596324,'please veriy if the parameters are updated or not')
# Out:
# {'message': {'chat': {'first_name': 'sudhanshu',
#                       'id': 1039725953,
#                       'type': 'private',
#                       'username': 'Sudhanshu_883'},
#              'date': 1630245847,
#              'document': {'file_id': 'BQACAgUAAxkBAAI-ImErk9eba_eD0x7jZodI0DcMnzS4AAJuAwACBExZVQHCNZehEXQDIAQ',
#                           'file_name': 'parameters.csv',
#                           'file_size': 387,
#                           'file_unique_id': 'AgADbgMAAgRMWVU',
#                           'mime_type': 'text/csv'},
#              'from': {'first_name': 'sudhanshu',
#                       'id': 1039725953,
#                       'is_bot': False,
#                       'language_code': 'en',
#                       'username': 'Sudhanshu_883'},
#              'message_id': 15906},
#  'update_id': 997768019}
# 'BQACAgUAAxkBAAI-ImErk9eba_eD0x7jZodI0DcMnzS4AAJuAwACBExZVQHCNZehEXQDIAQ'
# {'ok': True, 'result': {'file_id': 'BQACAgUAAxkBAAI-ImErk9eba_eD0x7jZodI0DcMnzS4AAJuAwACBExZVQHCNZehEXQDIAQ', 'file_unique_id': 'AgADbgMAAgRMWVU', 'file_size': 387, 'file_path': 'documents/file_0.csv'}}
# {'message_id': 16432,
#  'from': {'id': 1913570782,
#   'is_bot': True,
#   'first_name': 'binance_strategy',
#   'username': 'binance_883_bot'},
#  'chat': {'id': 665596324,
#   'first_name': 'Nicolas',
#   'last_name': '♛',
#   'username': 'nicolascane',
#   'type': 'private'},
#  'date': 1630246592,
#  'text': 'please veriy if the parameters are updated or not'}

# %%
import pandas as pd
df3 = pd.read_csv("parameters.csv")
df3['value'].iloc[-1]='off'

# %%
df3
